# %% [markdown]
# ### Reproduce Table 1 (the Molecular Captioning task)

# %%
from hme.metrics.mol2text_metrics import eval_mol2text
file_path= './captioning/result.jsonl'
#Evaluate the model's performance
results=eval_mol2text(input_file=file_path)
#Show the reuslts: bleu2, bleu4, rouge_1, rouge_2, rouge_l, meteor_score
print(f"BLEU-2: {100*results[0]:.2f}")
print(f"BLEU-4: {100*results[1]:.2f}")
print(f"ROUGE-1: {100*results[2]:.2f}")
print(f"ROUGE-2: {100*results[3]:.2f}")
print(f"ROUGE-L: {100*results[4]:.2f}")
print(f"METEOR: {100*results[5]:.2f}")
# Out:
# Evaluating: 100%|██████████| 2000/2000 [00:09<00:00, 215.91it/s]
# BLEU-2: 46.70
# BLEU-4: 39.70
# ROUGE-1: 51.30
# ROUGE-2: 38.16
# ROUGE-L: 46.16
# METEOR: 48.38

# %% [markdown]
# ### Reproduce Table 1 (the Molecular General QA task)

# %%
from hme.metrics.mol2text_metrics import eval_mol2text
file_path= './general-qa/result.jsonl'
#Evaluate the model's performance
results=eval_mol2text(input_file=file_path)
#Show the reuslts: bleu2, bleu4, rouge_1, rouge_2, rouge_l, meteor_score
print(f"BLEU-2: {100*results[0]:.2f}")
print(f"BLEU-4: {100*results[1]:.2f}")
print(f"ROUGE-1: {100*results[2]:.2f}")
print(f"ROUGE-2: {100*results[3]:.2f}")
print(f"ROUGE-L: {100*results[4]:.2f}")
print(f"METEOR: {100*results[5]:.2f}")
# Out:
# Evaluating: 100%|██████████| 10000/10000 [00:09<00:00, 1058.60it/s]
# BLEU-2: 54.06
# BLEU-4: 45.70
# ROUGE-1: 58.59
# ROUGE-2: 43.25
# ROUGE-L: 54.53
# METEOR: 59.67

# %% [markdown]
# ### Reproduce Supplementary Table 12 (the Molecular Property QA task)

# %%
from hme.metrics.number_metrics import eval_number
file_path= './property-qa/result.jsonl'
#Evaluate the model's performance
results=eval_number(input_file=file_path)
#Print the MAE
formatted = [f"{item:.2f}" for item in results]
print(f"MAE: {', '.join(formatted[:4])}")
# Out:
# Processing...: 100%|██████████| 7785/7785 [00:00<00:00, 83144.24it/s]
# weight: valid ratio is 0.9990; total is 2000
# logp: valid ratio is 1.0000; total is 1785
# topological polar surface area: valid ratio is 0.9985; total is 2000
# complexity: valid ratio is 0.9990; total is 2000
# weight: RMSE value is 16.3248
# logp: RMSE value is 0.7365
# topological polar surface area: RMSE value is 8.7146
# complexity: RMSE value is 86.4080
# MAE: 6.59, 0.41, 3.24, 20.54
